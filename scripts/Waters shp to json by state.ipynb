# %%
import geopandas
import us

# %%
usa_water= geopandas.read_file('/home/dan/Downloads/USA Detailed Water/USA_Detailed_Water_Bodies.shp')
states = geopandas.read_file('zip://tl_2017_us_state.zip')

# %%
sample  = usa_water_states.sample(n= 100)
for index, row in sample.iterrows():
    print(row['c1'], row['c2'])

# %%
usa_water_states = geopandas.sjoin(usa_water,states,how="inner", op='within')

# %%
usa_water_states[usa_water_states.STATEFP ==us.STATES_CONTIGUOUS[i].fips].plot()
#usa_water_states.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
for i in range(48):
    print(f'{i} {us.STATES_CONTIGUOUS[i].fips}')
    usa_water_states[usa_water_states.STATEFP ==us.STATES_CONTIGUOUS[i].fips].to_file(f'{us.STATES_CONTIGUOUS[i].fips}.json',driver='GeoJSON' )
# Out:
# 0 01
# 1 04
# 2 05
# 3 06
# 4 08
# 5 09
# 6 10
# 7 11
# 8 12
# 9 13
# 10 16
# 11 17
# 12 18
# 13 19
# 14 20
# 15 21
# 16 22
# 17 23
# 18 24
# 19 25
# 20 26
# 21 27
# 22 28
# 23 29
# 24 30
# 25 31
# 26 32
# 27 33
# 28 34
# 29 35
# 30 36
# 31 37
# 32 38
# 33 39
# 34 40
# 35 41
# 36 42
# 37 44
# 38 45
# 39 46
# 40 47
# 41 48
# 42 49
# 43 50
# 44 51
# 45 53
# 46 54
# 47 55
