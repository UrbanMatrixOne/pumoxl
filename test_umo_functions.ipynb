# %%
import scripts.census
lat,lon = 38,-80 #somwhere in WV ?

# %%
scripts.census.getStates()
# Out:
#    REGION DIVISION STATEFP   STATENS GEOID STUSPS  \
# 0       3        5      54  01779805    54     WV
# 1       3        5      12  00294478    12     FL
# 2       2        3      17  01779784    17     IL
# 3       2        4      27  00662849    27     MN
# 4       3        5      24  01714934    24     MD
# 5       1        1      44  01219835    44     RI
# 6       4        8      16  01779783    16     ID
# 7       1        1      33  01779794    33     NH
# 8       3        5      37  01027616    37     NC
# 9       1        1      50  01779802    50     VT
# 10      1        1      09  01779780    09     CT
# 11      3        5      10  01779781    10     DE
# 12      4        8      35  00897535    35     NM
# 13      4        9      06  01779778    06     CA
# 14      1        2      34  01779795    34     NJ
# 15      2        3      55  01779806    55     WI
# 16      4        9      41  01155107    41     OR
# 17      2        4      31  01779792    31     NE
# ...

# %%
import scripts.imagery

scripts.imagery.downloadGoogleImage(lat,lon,zoom_factor=18, full_path='./data/images/png/foo.png').shape
# Out:
# (224, 224, 3)

# %%
scripts.census.getDataAndImageForPoint(lat,lon,'pct_under_poverty_line', .05)
# Out:
# /home/dan/anaconda3/envs/census-env-two/lib/python3.6/site-packages/cenpy/remote.py:172: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   df[cols] = df[cols].convert_objects(convert_numeric=convert_numeric)
# /home/dan/anaconda3/envs/census-env-two/lib/python3.6/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# (    STATEFP COUNTYFP TRACTCE        GEOID  NAME           NAMELSAD  MTFCC  \
#  200      54      025  950100  54025950100  9501  Census Tract 9501  G5020
#
# ...

# %%
import scripts.water
# Out:
# (1, 12)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-ec6bd8dab364> in <module>()
# ----> 1 import scripts.water
#       2 water.getWaterDataForPoint(lat,lon)
#
# ~/gitprojects/sandbox/pumoxl/scripts/water.py in <module>()
#      30
#      31
# ---> 32 getWaterDataForPoint(  Latitude_in,Longitude_in )
#
# ~/gitprojects/sandbox/pumoxl/scripts/water.py in getWaterDataForPoint(Latitude_in, Longitude_in, buffer_dist)
#      23     satellite_ax = plt.imshow(satellite_img, interpolation='nearest')
#      24
# ---> 25     water_geodata_buffer.plot(ax = satellite_ax)
#      26
#      27     user_point.plot(ax = base, marker = '+',color = 'red',markersize = 100)
#
# ~/anaconda3/envs/census-env-two/lib/python3.6/site-packages/geopandas/geodataframe.py in plot(self, *args, **kwargs)
#     467     def plot(self, *args, **kwargs):
#     468
# ...

# %%
water.getWaterDataForPoint(lat,lon)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-b7dd55c4dc0a> in <module>()
# ----> 1 water.getWaterDataForPoint(lat,lon)
#
# NameError: name 'water' is not defined
